# %%
import pickle as pkl
import pandas as pd

# %%
loc_info=pkl.load(open('good_data/loc_info.pkl','rb'))

# %%
loc_info
# Out:
# {'Alcatraz Island': ['None',
#   ['Nature & Parks',
#    'Sights & Landmarks',
#    'Nature & Wildlife Areas',
#    'National Parks',
#    'Islands',
#    'Historic Sites']],
#  'Golden Gate Bridge': ['None', ['Sights & Landmarks', 'Bridges']],
#  'Cable Cars': ['None', ['Transportation', 'Tramways']],
#  'Lombard Street': ['None',
#   ['Sights & Landmarks', 'Points of Interest & Landmarks']],
#  'Sightseeing Tours in San Francisco': ['4',
#   ['Vantigo Tours', '1,414 Reviews ']],
#  'City Tours in San Francisco': ['4', ['Vantigo Tours', '1,414 Reviews ']],
#  'Pier 39': ['4', ['Sights & Landmarks', 'Piers & Boardwalks']],
#  'Walking Tours in San Francisco': ['4',
#   ['San Francisco Native Tours', '217 Reviews ']],
#  'Private Tours in San Francisco': ['None',
#   ['Vantigo Tours', '1,414 Reviews ']],
#  'Wine Tours & Tastings in San Francisco': ['4',
#   ['Vantigo Tours', '1,414 Reviews ']],
#  'Boat Tours in San Francisco': ['4', ['Bay Voyager', '527 Reviews ']],
# ...
