# %%
import pickle as pkl
import pandas as pd

# %%
entrance_fees=pkl.load(open('entrance_fees.pkl','rb'))
final_attractions=pkl.load(open('final_attractions_dict.pkl','rb'))
hotel_index=pkl.load(open('hotel_index.pkl','rb'))
hotel_to_dest=pkl.load(open('hotel_to_dest.pkl','rb'))
visit_length=pkl.load(open('visit_length.pkl','rb'))

# %%
# Out:
# Untitled.ipynb              hotel_index.pkl
# entrance_fees.pkl           hotel_to_dest.pkl
# final_attractions_dict.pkl  visit_length.pkl

# %%
travel_times=pkl.load(open('/Users/williamcottrell72/MyGit/TravelApp/good_data/travel_times.pkl','rb'))

# %%
len(travel_times)
# Out:
# 609

# %%
travel_times[0]
# Out:
# array([ 0. , 24.2,  9.9,  5.5,  8.8, 11. , 13.2,  2.2, 20.9, 29.7, 16.5,
#        17.6, 17.6, 28.6, 12.1, 16.5,  8.8, 20.9,  9.9, 31.9, 25.3, 25.3,
#        29.7, 28.6, 30.8, 20.9,  7.7,  4.4,  4.4, 28.6, 18.7, 12.1,  8.8,
#         9.9, 13.2, 23.1, 31.9, 24.2,  7.7, 34.1,  6.6,  9.9, 31.9, 28.6,
#        26.4,  2.2, 15.4,  5.5,  5.5, 23.1, 13.2,  8.8,  8.8, 14.3, 18.7,
#        12.1, 14.3, 19.8, 16.5, 40.7, 28.6, 25.3, 25.3,  6.6, 16.5, 16.5,
#         6.6, 12.1, 17.6, 15.4, 19.8, 13.2, 15.4, 27.5,  5.5, 14.3, 26.4,
#         8.8, 34.1, 20.9,  8.8,  9.9,  8.8, 20.9, 23.1, 34.1, 16.5, 16.5,
#         2.2, 31.9,  8.8, 19.8,  6.6, 28.6,  8.8, 27.5,  7.7, 22. ,  9.9,
#        12.1, 20.9,  6.6, 31.9,  6.6, 27.5, 28.6, 19.8, 24.2,  7.7, 30.8,
#        14.3, 15.4, 30.8, 16.5, 14.3, 28.6,  5.5, 11. , 19.8, 42.9,  8.8,
#        25.3,  3.3,  5.5, 20.9, 19.8, 22. ,  6.6, 15.4, 13.2, 15.4, 12.1,
#        13.2,  8.8, 16.5, 17.6,  5.5, 14.3, 16.5, 28.6, 35.2, 15.4,  6.6,
# ...
