# %%
import pandas as pd
import numpy as pd
import pickle as pkl

# %%
fpl=pkl.load(open('full_place_list.pkl','rb'))

# %%
fpl=pkl.load(open('SF_authors.pkl','rb'))

# %%
# Out:
# ['61georgiaboy',
#  '12iguasu13',
#  'Jacob S',
#  'jancolly2018',
#  'AnnieM452',
#  'Mismel2kl',
#  'SunnyDude61049',
#  '378vinaym',
#  'JJBurnie',
#  'Meghan T',
#  'TripletA',
#  'peter wyatt m',
#  'DavidDundonald',
#  'Jamie W',
#  'Sandra S',
#  'RippyWilliams',
#  'gymmama50',
#  'hasyed',
#  'Christopher O',
#  'Ali V',
#  'Chante W',
#  'Horacio B',
#  'LauraT2211',
#  'Chris V',
#  'TravlinLM',
#  'TerryCIII',
#  'Kevin F',
#  'palebutterfly',
#  'Mary F',
#  'Wakez4',
#  'Kimberley J',
#  'Chiara C',
#  'Eileen O',
#  'Gavin M',
#  'deb47Surrey',
#  'tjsm2018',
#  'Noel A',
#  'Korie B',
#  'Cali_Doll',
#  'TomGSt_Albans',
#  'NAF22',
#  'quangfremont',
#  'YaelSwitzerland',
#  'TranzorZ1985',
#  'Russell N',
#  'Faye O',
#  'Alan G',
#  'Katsi C',
#  'jayashreesatish92',
#  'Marie1212',
#  'HeidelbergSummer',
#  'A J',
#  'ninasky77',
#  'ShwetaTheExplorer',
#  'Jacqueline J',
#  'TravelinSuz',
#  'Jonathan G',
#  'Miguel P',
#  'Mark H',
#  'Joie A',
#  'LAVAPAVA',
# ...
