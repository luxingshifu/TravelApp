# %%
import pickle as pkl

# %%
style_mapper=pkl.load(open('style_mapper.pkl','rb'))

# %%
style_mapper=pkl.load(open('style_mapper.pkl','rb'))

# %%
ta_features_dct=pkl.load(open('ta_feature_dct.pkl','rb'))

# %%
ta_features_dct
# Out:
# {'Alta': '',
#  'ZK Gallery': 'Art, Museum',
#  'The Barrel Room': 'Cuisine, Nightlife',
#  'Cornell Hotel De France': '',
#  'Sanraku at Metreon': 'Culture',
#  'One Market Restaurant': '',
#  'City View Restaurant': 'Culture',
#  'Lodge at the Presidio': 'Nature, History, Culture',
#  'Almanac Beer Taproom': 'Landmark, History',
#  'Travelodge by Wyndham Presidio San Francisco': 'Nature, History, Culture',
#  'Walt Disney Family Museum': 'Fun & Entertainment, Culture, Museum',
#  '54 Mint': 'Culture',
#  'China Live': '',
#  'Cafe Claude': '',
#  'Blue & Gold Fleet, PIER 39': 'Landmark, Fun & Entertainment, Shopping',
#  'Acquerello': '',
#  'Inn at the Presidio': 'Nature, History, Culture',
#  'Super Duper Burgers': 'Culture',
#  'B44': 'Culture',
#  'Frances': '',
#  'Rickhouse': 'Nightlife',
#  'Adventure Cat Sailing Charters': 'Tour',
#  'War Memorial Opera House': 'Nightlife, Art, Culture',
#  'Capital Restaurant': 'Culture',
#  'San Francisco City Guides': 'Tour',
# ...
